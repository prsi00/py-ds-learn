# %%
print("Hello World!")
# Out:
# Hello World!

# %%
a = "Hello World"

# %%
a.upper()
# Out:
# 'HELLO WORLD'

# %%
a.lower()
# Out:
# 'hello world'

# %%
a.title()
# Out:
# 'Hello World'

# %%
a.count("l")
# Out:
# 3

# %%
a.replace("o","u")
# Out:
# 'Hellu Wurld'

# %%
'I\'m'
# Out:
# "I'm"

# %%
'I'm'
# Out:
#   Cell In[14], line 1
#     'I'm'
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
f'{a} ki{a}'
# Out:
# 'Hello World kiHello World'

# %%
list = ['Vansh','Ansh','Ruhi','Golu']

# %%
list
# Out:
# ['Vansh', 'Ansh', 'Ruhi', 'Golu']

# %%
list1=list

# %%
list1
# Out:
# ['Vansh', 'Ansh', 'Ruhi', 'Golu']

# %%
list1=list[:]
list1
# Out:
# ['Vansh', 'Ansh', 'Ruhi', 'Golu']

# %%
list1=list.copy()
list1
# Out:
# ['Vansh', 'Ansh', 'Ruhi', 'Golu']

# %%
list1.append("Vansh")
list1
# Out:
# ['Ansh', 'Ruhi', 'Golu', 'Vansh']

# %%
list1
list1.remove("Vansh")
list1
# Out:
# ['Ansh', 'Ruhi', 'Golu']

# %%
dict={'name':'Priyesh', 'age' : 22, 1 : 'name' , 2 : 'age'}

# %%
dict
# Out:
# {'name': 'Priyesh', 'age': 22, 1: 'name', 2: 'age'}

# %%
dict.keys()
# Out:
# dict_keys(['name', 'age', 1, 2])

# %%
dict.values()
# Out:
# dict_values(['Priyesh', 22, 'name', 'age'])

# %%
dict.items()
# Out:
# dict_items([('name', 'Priyesh'), ('age', 22), (1, 'name'), (2, 'age')])

# %%
 len(dict)
# Out:
# 4

# %%
dict1={'a':1 ,'a':0,'b':2}

# %%
dict1
# Out:
# {'a': 0, 'b': 2}

# %%
dict1.keys()
# Out:
# dict_keys(['a', 'b'])

# %%
dict1.values()
# Out:
# dict_values([0, 2])

# %%
dict1.items()
# Out:
# dict_items([('a', 0), ('b', 2)])

# %%
type(dict1['a'])
# Out:
# int

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/priyesh/Dev/py-ds-learn'

# %%
os.listdir()
# Out:
# ['New Folder',
#  'Untitled.ipynb',
#  'README.md',
#  'Example.ipynb',
#  '.ipynb_checkpoints',
#  '.git']

# %%
os.makedirs("New Folder")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 os.makedirs("New Folder")
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [Errno 17] File exists: 'New Folder'
